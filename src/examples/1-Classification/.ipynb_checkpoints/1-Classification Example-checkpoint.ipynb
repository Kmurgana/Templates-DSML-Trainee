# %% [markdown]
# # **<span style="color:#00C853;">Schneider Electric Hackathon </span>**

# %% [markdown]
# > This notebook is part of a Hackathon held by nuwe.io on 05/21/2022.
# >
# > To get the API key, create an account in the [website](https://nuwe.io/challenge/data-science-se) .

# %% [markdown]
# #### Background
# ----------------------------------------------------------------------------------------------------------
#
# The EU contributes 18% of total global warming gas emissions; However, it is increasingly determined to take the lead in the fight against climate change. That is why it has set itself the goal of reaching zero carbon emissions by 2050.
#
# To this end, it has put in place a wealth of resources to help achieve this goal over the next few years, and it will need your help to do so.

# %% [markdown]
# ### Dataset
# This dataset contains data on industrial facilities and emissions across Europe.
# The dataset will consist of the following variables of interest:
#
# __countryName__: Country in which the facility is located
#
# __EPRETRSectorCode__: Code of the sector in which the company specialises
#
# __eptrSectorName__: Name of the sector in which it specialises
#
# __EPRTRAnnexIMainActivityCode__: Code of the specialisation within the sector in which they operate
#
# __EPRTRAnnexIMainActivityLabel__: Specialisation within the sector in which they operate
#
# __FacilityInspireID__: Building identifier
#
# __facilityName__: Name of the building in which the activity takes place
#
# __City__: City in which the facility is located
#
# __CITY ID__: ID to confirm location
#
# __targetRelease__: Type of polluter to study
#
# __pollutant__: Type of pollutant emitted (Target variable). In order to follow the same standard, you must encode this variables as follows:
#
# | pollutant |	number |
# | ------ | ---------|
# |Nitrogen oxides (NOX) |	0 |
# |Carbon dioxide (CO2)	|1    |
# |Methane (CH4)	|  2      |
#
# __DAY__: Day on which the report is made
#
# __MONTH__: Reporting month
#
# __reportingYear__: Reporting year
#
# __CONTINENT__: Continent on which the company is located
#
# __max_wind_speed__: Maximum wind speed
#
# __avg_wind_speed__: Average wind speed
#
# __min_wind_speed__: Minimum wind speed
#
# __max_temp__: Maximum temperature
#
# __avg_temp__: Average temperature
#
# __min_temp__: Minimum temperature
#
# __DAYS WITH FOG__: Total days of the month recorded in the area
#
# __REPORTER NAME__: Reporter's name

# %% [markdown]
# The dataset is split into Training Dataset and Testing Dataset.
#
# <img src=" https://challenges-asset-files.s3.us-east-2.amazonaws.com/data_sets/Data-Science/4+-+events/SchneiderElectricES22/final/images/fragmentation_green.png ">
#
# To train the model, the training dataset has to be used. It is fragmented in different datasets and in different formats.

# %% [markdown]
# **Roadmap**
#
# Before we dive headlong into programming, we should outline a brief guide to keep us on track. The following steps form the basis of any machine learning workflow once we have a problem and a model in mind:
#
# * 1) Raising the question.
# * 2) Acquiring the data.
# * 3) Adapting information, identifying and correcting anomalies (EDA).
# * 4) Preparar los datos para el modelo de aprendizaje automático.
# * 5) Training the model with training data.
# * 6) Making predictions with test data.
# * 7) Compare predictions with test data.
# * 8) Adjust the model.
# * 9) Results presentation.

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ## ✅1) Raising the question  ❓
#
# The exercise consists of obtaining a predictive model capable of classifying whether the variable __pollutant__ is going to be Nitrogen oxides (NOX), Carbon dioxide (CO2) or Methane (CH4), according to the oder variables for which it would be **objective** for the model to be as accurate as possible.
#
# **NOTE**: For in this case, the client already informs us how the coding of the output variables should be.

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ## ✅ 2) Acquiring the data  🔍
#
# ### **<span style="color:#43A047;">2.1 Importing required libraries. </span>**

# %%
# Data acquirement and processing
# ======================================================================================
import pandas as pd
import json
import numpy as np 
import nltk
import datetime as dt

# Graphics
# ======================================================================================
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing 
# ======================================================================================
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split

# NLP (Natural Language Programming) 
# ======================================================================================
import string
import re
import nltk 
import fitz
from nltk.util import pr
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob

# Modeling for a categorical target
# ======================================================================================
from sklearn.linear_model import LogisticRegression   
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC 

# Testing and validating
# ======================================================================================
from sklearn.metrics import precision_score, recall_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import ShuffleSplit, cross_val_score, GridSearchCV
from sklearn.inspection import permutation_importance
import multiprocessing

# Warnings Configuration
# ======================================================================================
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### **<span style="color:#43A047;">2.2 Reading data from CSV </span>**
#
# #### **<span style="color:#4CAF50;">2.2.1 Reading first data CSV </span>**

# %%
data1_csv_df = pd.read_csv("../1-Classification/datasets/train1.csv", sep=',') #1-Loading the first csv

# %%
data1_csv_df.head() #2-We look at the heading and check that it was read correctly.
# Out:
#   countryName                  eprtrSectorName  \
# 0     Germany                 Mineral industry
# 1       Italy                 Mineral industry
# 2       Spain  Waste and wastewater management
# 3     Czechia                    Energy sector
# 4     Finland  Waste and wastewater management
#
#                         EPRTRAnnexIMainActivityLabel  \
# 0  Installations for the production of cement cli...
# 1  Installations for the production of cement cli...
# 2  Landfills (excluding landfills of inert waste ...
# 3  Thermal power stations and other combustion in...
# 4                 Urban waste-water treatment plants
#
#                                    FacilityInspireID  \
# 0  https://registry.gdi-de.org/id/de.ni.mu/062217...
# 1                         IT.CAED/240602021.FACILITY
# 2                         ES.CAED/001966000.FACILITY
# 3                    CZ.MZP.U422/CZ34736841.FACILITY
# 4  http://paikkatiedot.fi/so/1002031/pf/Productio...
#
#                                         facilityName                  City  \
# 0               Holcim (Deutschland) GmbH Werk Höver                Sehnde
# 1               Stabilimento di Tavernola Bergamasca  TAVERNOLA BERGAMASCA
# 2                  COMPLEJO MEDIOAMBIENTAL DE ZURITA    PUERTO DEL ROSARIO
# 3                                Elektrárny Prunéřov                 Kadaň
# 4  TAMPEREEN VESI LIIKELAITOS, VIINIKANLAHDEN JÄT...               Tampere
#
#   targetRelease              pollutant  reportingYear  MONTH  ...  CONTINENT  \
# 0           AIR   Carbon dioxide (CO2)           2015     10  ...     EUROPE
# 1           AIR  Nitrogen oxides (NOX)           2018      9  ...     EUROPE
# 2           AIR          Methane (CH4)           2019      2  ...     EUROPE
# 3           AIR  Nitrogen oxides (NOX)           2012      8  ...     EUROPE
# 4           AIR          Methane (CH4)           2018     12  ...     EUROPE
#
#   max_wind_speed  avg_wind_speed  min_wind_speed   max_temp   avg_temp  \
# 0      15.118767       14.312541       21.419106   2.864895   4.924169
# 1      19.661550       19.368166       21.756389   5.462839   7.864403
# 2      12.729453       14.701985       17.103930   1.511201   4.233438
# 3      11.856417       16.122584       17.537184  10.970301  10.298348
# 4      17.111930       20.201604       21.536012  11.772039  11.344078
#
#     min_temp  DAY WITH FOGS     REPORTER NAME  \
# 0   9.688206              2  Mr. Jacob Ortega
# 1  12.023521              1    Ashlee Serrano
# 2   8.632193              2      Vincent Kemp
# 3  15.179215              0        Carol Gray
# 4  16.039004              2        Blake Ford
#
#                             CITY ID
# 0  7cdb5e74adcb2ffaa21c1b61395a984f
# 1  cd1dbabbdba230b828c657a9b19a8963
# 2  5011e3fa1436d15b34f1287f312fbada
# 3  37a6d7a71c4f7c2469e4f01b70dd90c2
# 4  471fe554e1c62d1b01cc8e4e5076c61a
#
# [5 rows x 21 columns]

# %%
data1_csv_df.shape #3-Quickly we check the format
# Out:
# (18563, 21)

# %% [markdown]
# #### **<span style="color:#4CAF50;">2.2.2 Reading second data CSV </span>**

# %%
data2_csv_df = pd.read_csv("../1-Classification/datasets/train3.csv") #1-Loading the second csv

# %%
data2_csv_df.head() #2-We look at the heading and check that it was read correctly.
# Out:
#    Unnamed: 0  Unnamed: 1                           CITY ID CONTINENT  \
# 0           0       47068  4c325d62c064477ef17b4c6e4437e121    EUROPE
# 1           1       32952  f5e609e7095f91cc8ce9ed6d8e774a0d    EUROPE
# 2           2       72375  cfab1ba8c67c7c838db98d666f02a132    EUROPE
# 3           3       40702  95b4e51f7b662598134e1eb956407c74    EUROPE
# 4           4       29884  f4433be3b1bfaeeb0633eb65d04b1325    EUROPE
#
#                   City  DAY  DAY WITH FOGS EPRTRAnnexIMainActivityCode  \
# 0  Europoort Rotterdam    2              1                        4(a)
# 1                 RION    3              2                        3(c)
# 2                   --    1             12                        1(c)
# 3             DRIZZONA   17              1                        7(a)
# 4                Lünen    6              0                        5(a)
#
#                         EPRTRAnnexIMainActivityLabel  EPRTRSectorCode  ...  \
# 0  Chemical installations for the production on a...                4  ...
# 1  Installations for the production of cement cli...                3  ...
# 2  Thermal power stations and other combustion in...                1  ...
# 3  Installations for the intensive rearing of pou...                7  ...
# 4  Installations for the recovery or disposal of ...                5  ...
#
#       countryName                                 eprtrSectorName  \
# 0     Netherlands                               Chemical industry
# 1          Greece                                Mineral industry
# 2  United Kingdom                                   Energy sector
# 3           Italy  Intensive livestock production and aquaculture
# 4         Germany                 Waste and wastewater management
#
#                                         facilityName   max_temp  \
# 0                        Indorama Ventures Europe BV  13.256816
# 1                  TITAN CEMENT S.A. - DREPANO PLANT   4.528859
# 2                                    Cormorant Alpha  10.669133
# 3  SOCIETA' AGRICOLA SPARAVALLE DI FERRARI GIUSEP...   7.095682
# 4                       Biomassekraftwerk Lünen GmbH   9.886774
#
#    max_wind_speed   min_temp min_wind_speed              pollutant  \
# 0       11.019329  14.696895      20.899762   Carbon dioxide (CO2)
# 1       14.512395   9.219003      23.243403  Nitrogen oxides (NOX)
# 2       20.262171  14.715465      23.956529  Nitrogen oxides (NOX)
# 3       18.283547  13.582024      26.696266          Methane (CH4)
# 4       13.759408  14.006226      24.768933   Carbon dioxide (CO2)
#
#    reportingYear  targetRelease
# 0           2020            AIR
# 1           2019            AIR
# 2           2009            AIR
# 3           2014            AIR
# 4           2015            AIR
#
# [5 rows x 25 columns]

# %%
data2_csv_df.shape #3-Quickly we check the format
# Out:
# (9500, 25)

# %% [markdown]
# So, the first 50% of the data is already loaded, let's proceed with the rest.

# %% [markdown]
# ### **<span style="color:#43A047;">2.3 Reading data from API json </span>**
#
# #### **<span style="color:#4CAF50;">2.3.1. Reading first json data </span>**

# %%
url = 'http://schneiderapihack-env.eba-3ais9akk.us-east-2.elasticbeanstalk.com/first'
data1_js_df = pd.read_json(url)

# %%
data1_js_df.head() #2-We look at the heading and check that it was read correctly.
# Out:
#                                    CITY ID CONTINENT                 City  \
# 0  47068  4c325d62c064477ef17b4c6e4437e121    EUROPE  Europoort Rotterdam
# 1  32952  f5e609e7095f91cc8ce9ed6d8e774a0d    EUROPE                 RION
# 2  72375  cfab1ba8c67c7c838db98d666f02a132    EUROPE                   --
# 3  40702  95b4e51f7b662598134e1eb956407c74    EUROPE             DRIZZONA
# 4  29884  f4433be3b1bfaeeb0633eb65d04b1325    EUROPE                Lünen
#
#    DAY  DAY WITH FOGS EPRTRAnnexIMainActivityCode  \
# 0    2              1                        4(a)
# 1    3              2                        3(c)
# 2    1             12                        1(c)
# 3   17              1                        7(a)
# 4    6              0                        5(a)
#
#                         EPRTRAnnexIMainActivityLabel  EPRTRSectorCode  \
# 0  Chemical installations for the production on a...                4
# 1  Installations for the production of cement cli...                3
# 2  Thermal power stations and other combustion in...                1
# 3  Installations for the intensive rearing of pou...                7
# 4  Installations for the recovery or disposal of ...                5
#
#                                    FacilityInspireID  ...     countryName  \
# 0                         NL.RIVM/000019070.FACILITY  ...     Netherlands
# 1                            EL.CAED/100075.FACILITY  ...          Greece
# 2         UK.CAED/BEISOffsh-Cormorant-Alpha.FACILITY  ...  United Kingdom
# 3                         IT.CAED/260342003.FACILITY  ...           Italy
# 4  https://registry.gdi-de.org/id/de.nw.inspire.p...  ...         Germany
#
#                                   eprtrSectorName  \
# 0                               Chemical industry
# 1                                Mineral industry
# 2                                   Energy sector
# 3  Intensive livestock production and aquaculture
# 4                 Waste and wastewater management
#
#                                         facilityName   max_temp  \
# 0                        Indorama Ventures Europe BV  13.256816
# 1                  TITAN CEMENT S.A. - DREPANO PLANT   4.528859
# 2                                    Cormorant Alpha  10.669133
# 3  SOCIETA' AGRICOLA SPARAVALLE DI FERRARI GIUSEP...   7.095682
# 4                       Biomassekraftwerk Lünen GmbH   9.886774
#
#   max_wind_speed   min_temp min_wind_speed              pollutant  \
# 0      11.019329  14.696895      20.899762   Carbon dioxide (CO2)
# 1      14.512395   9.219003      23.243403  Nitrogen oxides (NOX)
# 2      20.262171  14.715465      23.956529  Nitrogen oxides (NOX)
# 3      18.283547  13.582024      26.696266          Methane (CH4)
# 4      13.759408  14.006226      24.768933   Carbon dioxide (CO2)
#
#    reportingYear  targetRelease
# 0           2020            AIR
# 1           2019            AIR
# 2           2009            AIR
# 3           2014            AIR
# 4           2015            AIR
#
# [5 rows x 24 columns]

# %%
data1_js_df.shape #3-Quickly we check the format
# Out:
# (9500, 24)

# %%
data1_js_df.to_csv("../1-Classification/datasets/train3.csv") #Saving the data set in our directory

# %% [markdown]
# #### **<span style="color:#4CAF50;">2.3.2. Reading second json data </span>**

# %%
url = 'http://schneiderapihack-env.eba-3ais9akk.us-east-2.elasticbeanstalk.com/second'
data2_js_df = pd.read_json(url)

# %%
data2_js_df.head() #2-We look at the heading and check that it was read correctly.
# Out:
#                                    CITY ID CONTINENT        City  DAY  \
# 0  66841  e8d4668a35daa00b7802cdaac2b33bab    EUROPE     SIGTUNA   18
# 1  43952  3a9c3ae8ea2e275700947e511afca943    EUROPE      Kaunas    3
# 2  77831  3d7694a841fc5d426287f208f5e04f61    EUROPE  WORKINGTON   20
# 3  67548  f8a4753cdbccbd64f0411a207e071aac    EUROPE        SALA    5
# 4  67772  ce2ddff460389bd5d9f1152dc5679d20    EUROPE     Lugnvik   26
#
#    DAY WITH FOGS EPRTRAnnexIMainActivityCode  \
# 0              0                        1(c)
# 1              1                        1(c)
# 2             10                        6(b)
# 3              2                        5(d)
# 4              1                        1(c)
#
#                         EPRTRAnnexIMainActivityLabel  EPRTRSectorCode  \
# 0  Thermal power stations and other combustion in...                1
# 1  Thermal power stations and other combustion in...                1
# 2  Industrial plants for the production of paper ...                6
# 3  Landfills (excluding landfills of inert waste ...                5
# 4  Thermal power stations and other combustion in...                1
#
#              FacilityInspireID  ...     countryName  \
# 0    SE.CAED/10014262.Facility  ...          Sweden
# 1            LT.EEA/3.FACILITY  ...       Lithuania
# 2  UK.CAED/EW_EA-1427.FACILITY  ...  United Kingdom
# 3    SE.CAED/10021261.Facility  ...          Sweden
# 4    SE.CAED/10023054.Facility  ...          Sweden
#
#                             eprtrSectorName              facilityName  \
# 0                             Energy sector              BRISTAVERKET
# 1                             Energy sector           Kauno elektrine
# 2  Paper and wood production and processing    Workington Board Mill
# 3           Waste and wastewater management  Isätra avfallsanläggning
# 4                             Energy sector            Lugnviksverket
#
#     max_temp max_wind_speed   min_temp min_wind_speed              pollutant  \
# 0  12.910354      19.591152  17.822159      24.496401   Carbon dioxide (CO2)
# 1   1.566654       9.006533   4.398770      20.074976   Carbon dioxide (CO2)
# 2  10.241999      14.076643  13.447854      25.239151  Nitrogen oxides (NOX)
# 3  12.684851      18.924086  17.377168      25.603714          Methane (CH4)
# 4   7.826782      18.596857  11.731918      25.811989   Carbon dioxide (CO2)
#
#    reportingYear  targetRelease
# 0           2010            AIR
# 1           2015            AIR
# 2           2015            AIR
# 3           2013            AIR
# 4           2014            AIR
#
# [5 rows x 24 columns]

# %%
data2_js_df.shape #3-Quickly we check the format
# Out:
# (9500, 24)

# %%
data2_js_df.to_csv("../1-Classification/datasets/train4.csv") #Saving the data set in our directory

# %% [markdown]
# #### **<span style="color:#4CAF50;">2.3.2. Reading thrid json data </span>**

# %%
url = 'http://schneiderapihack-env.eba-3ais9akk.us-east-2.elasticbeanstalk.com/third'
data3_js_df = pd.read_json(url)

# %%
data3_js_df.head() #2-We look at the heading and check that it was read correctly.
# Out:
#                                    CITY ID CONTINENT       City  DAY  \
# 0  41175  7951666b94e0f0891e0c66b2381fca55    EUROPE     TORINO   24
# 1  49299  33c89df2492e8d3efda719c849b530ea    EUROPE       Łódź    4
# 2  34879  4a8b9d98f65af3a29bbf298d8536c142    EUROPE  Tipperary   18
# 3  16905  e38f45f4d669e9f69fa97bfe049ceed6    EUROPE      REIMS   27
# 4  75675  fb960490e42477cbfdcd6bab1793f31e    EUROPE     Hexham   28
#
#    DAY WITH FOGS EPRTRAnnexIMainActivityCode  \
# 0              1                        1(c)
# 1              0                        1(c)
# 2              0                    7(a)(ii)
# 3              0                        3(e)
# 4              2                        6(b)
#
#                         EPRTRAnnexIMainActivityLabel  EPRTRSectorCode  \
# 0  Thermal power stations and other combustion in...                1
# 1  Thermal power stations and other combustion in...                1
# 2  Installations for the intensive rearing of pig...                7
# 3  Installations for the manufacture of glass, in...                3
# 4  Industrial plants for the production of paper ...                6
#
#             FacilityInspireID  ...     countryName  \
# 0  IT.CAED/101511001.FACILITY  ...           Italy
# 1        PL.EEA/1321.FACILITY  ...          Poland
# 2      IE.CAED/P0489.FACILITY  ...         Ireland
# 3       FR.CAED/3453.FACILITY  ...          France
# 4   UK.LAED/E375_434.FACILITY  ...  United Kingdom
#
#                                   eprtrSectorName  \
# 0                                   Energy sector
# 1                                   Energy sector
# 2  Intensive livestock production and aquaculture
# 3                                Mineral industry
# 4        Paper and wood production and processing
#
#                                         facilityName   max_temp  \
# 0                                Iren Energia S.p.A.   7.367005
# 1            Dalkia Łódź S.A. Elektrociepłownia nr 3  12.764269
# 2  Glen of Aherlow Pig Producers Co-Op Society Li...   9.278435
# 3                      OI MANUFACTURING FRANCE REIMS  12.132210
# 4                                 EGGER (UK) LIMITED   3.376109
#
#   max_wind_speed   min_temp min_wind_speed              pollutant  \
# 0      15.892429  12.571580      20.467596  Nitrogen oxides (NOX)
# 1      14.168742  19.081248      25.439515   Carbon dioxide (CO2)
# 2      17.849098  15.912360      25.603904          Methane (CH4)
# 3      10.348395  16.897353      18.131688  Nitrogen oxides (NOX)
# 4      13.803120   6.435358      22.215066  Nitrogen oxides (NOX)
#
#    reportingYear  targetRelease
# 0           2015            AIR
# 1           2011            AIR
# 2           2011            AIR
# 3           2014            AIR
# 4           2012            AIR
#
# [5 rows x 24 columns]

# %%
columns=data3_js_df.columns.values.tolist()

# %%
columns
# Out:
# ['',
#  'CITY ID',
#  'CONTINENT',
#  'City',
#  'DAY',
#  'DAY WITH FOGS',
#  'EPRTRAnnexIMainActivityCode',
#  'EPRTRAnnexIMainActivityLabel',
#  'EPRTRSectorCode',
#  'FacilityInspireID',
#  'MONTH',
#  'REPORTER NAME',
#  'avg_temp',
#  'avg_wind_speed',
#  'countryName',
#  'eprtrSectorName',
#  'facilityName',
#  'max_temp',
#  'max_wind_speed',
#  'min_temp',
#  'min_wind_speed',
#  'pollutant',
#  'reportingYear',
#  'targetRelease']

# %%
data3_js_df.shape #3-Quickly we check the format
# Out:
# (9501, 24)

# %%
data3_js_df.to_csv("../1-Classification/datasets/train5.csv") #Saving the data set in our directory

# %% [markdown]
# So, the __99%__ of the data is already loaded.

# %% [markdown]
# ### **<span style="color:#43A047;">2.4 Reading data from PDF </span>**
#
# #### **<span style="color:#4CAF50;">2.4.1. Reading first PDF data. </span>**

# %% [markdown]
# I have used the PyMuPDF library for this purpose. This library provided many applications such as extracting images from PDF, extracting texts from different shapes, making annotations, draw a bounded box around the texts along with the features of libraries like PyPDF2.

# %%
folder = r"../train6/"
def get_files(folder):
    import os
    os.chdir(folder)
    files = os.listdir()
    files = [x for x in files if x.endswith(".pdf")]
    return files

# %%
#RUN FILE 
files = get_files(folder)

# %%
out = open("pdf_to_text.txt", "wb")  # open text output
for file in files:
    doc = fitz.open(folder + file)
    for page in doc:  # iterate the document pages
        text = page.get_text().encode("utf8")  # get plain text (is in UTF-8)
        out.write(text)  # write text of page
        out.write(bytes((12,)))  # write page delimiter (form feed 0x0C)
out.close()

# %%
all_annots = (open("pdf_to_text.txt", encoding="UTF-8")).readlines()

# %%
all_annots
# Out:
# ['REPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81597\n',
#  'FACILITY NAME:\n',
#  'Millerhill Recycling & Energy Recovery Centre\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200002651.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Millerhill, Dalkeith\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(b)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Nitrogen oxides (NOX)\n',
#  'emissions:\n',
#  '175000\n',
#  'DAY:\n',
#  '12\n',
#  'MONTH:\n',
#  '6 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,79E+15\n',
#  'min_wind_speed:\n',
#  '2,2E+16 avg_wind_speed: 2,04E+15\n',
#  'max_temp:\n',
#  '1,51E+16\n',
#  'min_temp:\n',
#  '1,82E+15 avg_temp:\n',
#  '1,71E+16\n',
#  'DAYS FOG:\n',
#  '10\n',
#  'REPORTER NAME:William Nelson\n',
#  'CITY_ID\n',
#  'c662b4b4d859a9c224b5ac0acf221748\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81516\n',
#  'FACILITY NAME:\n',
#  'Fife Ethylene Plant\n',
#  '81516\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000061.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Cowdenbeath\n',
#  'EPRTRSectorCode:\n',
#  '1\n',
#  'eprtrSectorName:\n',
#  'Energy sector\n',
#  'MainActivityCode:1(c)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Carbon dioxide (CO2)\n',
#  'emissions:\n',
#  '6,8E+08\n',
#  'DAY:\n',
#  '12\n',
#  'MONTH:\n',
#  '4 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,52E+16\n',
#  'min_wind_speed:\n',
#  '2,06E+15 avg_wind_speed: 1,46E+16\n',
#  'max_temp:\n',
#  '9,61E+15\n',
#  'min_temp:\n',
#  '1,33E+16 avg_temp:\n',
#  '8,69E+15\n',
#  'DAYS FOG:\n',
#  '19\n',
#  'REPORTER NAME:Shawn Graham\n',
#  'CITY_ID\n',
#  '3c563ab0d76fc84128574b5da82f769a\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81516\n',
#  'FACILITY NAME:\n',
#  'Fife Ethylene Plant\n',
#  '81517\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000061.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Cowdenbeath\n',
#  'EPRTRSectorCode:\n',
#  '1\n',
#  'eprtrSectorName:\n',
#  'Energy sector\n',
#  'MainActivityCode:1(c)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Carbon dioxide (CO2)\n',
#  'emissions:\n',
#  '6,8E+08\n',
#  'DAY:\n',
#  '12\n',
#  'MONTH:\n',
#  '4 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,52E+16\n',
#  'min_wind_speed:\n',
#  '2,06E+15 avg_wind_speed: 1,46E+16\n',
#  'max_temp:\n',
#  '9,61E+15\n',
#  'min_temp:\n',
#  '1,33E+16 avg_temp:\n',
#  '8,69E+15\n',
#  'DAYS FOG:\n',
#  '19\n',
#  'REPORTER NAME:Shawn Graham\n',
#  'CITY_ID\n',
#  '3c563ab0d76fc84128574b5da82f769a\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81517\n',
#  'FACILITY NAME:\n',
#  'Fife Ethylene Plant\n',
#  '81518\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000061.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Cowdenbeath\n',
#  'EPRTRSectorCode:\n',
#  '1\n',
#  'eprtrSectorName:\n',
#  'Energy sector\n',
#  'MainActivityCode:1(c)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Nitrogen oxides (NOX)\n',
#  'emissions:\n',
#  '633000\n',
#  'DAY:\n',
#  '3\n',
#  'MONTH:\n',
#  '1 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,16E+16\n',
#  'min_wind_speed:\n',
#  '2,18E+16 avg_wind_speed: 1,65E+16\n',
#  'max_temp:\n',
#  '8,03E+15\n',
#  'min_temp:\n',
#  '1,04E+16 avg_temp:\n',
#  '8,94E+15\n',
#  'DAYS FOG:\n',
#  '10\n',
#  'REPORTER NAME:Aaron Johnson\n',
#  'CITY_ID\n',
#  '3c563ab0d76fc84128574b5da82f769a\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81518\n',
#  'FACILITY NAME:\n',
#  'Alloa Glass Factory\n',
#  '81519\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000073.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Alloa\n',
#  'EPRTRSectorCode:\n',
#  '3\n',
#  'eprtrSectorName:\n',
#  'Mineral industry\n',
#  'MainActivityCode:3(e)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Carbon dioxide (CO2)\n',
#  'emissions:\n',
#  '1,49E+08\n',
#  'DAY:\n',
#  '9\n',
#  'MONTH:\n',
#  '11 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,11E+16\n',
#  'min_wind_speed:\n',
#  '2,03E+16 avg_wind_speed:\n',
#  '1,6E+16\n',
#  'max_temp:\n',
#  '-1,9E+16\n',
#  'min_temp:\n',
#  '4,07E+16 avg_temp:\n',
#  '1,33E+15\n',
#  'DAYS FOG:\n',
#  '4\n',
#  'REPORTER NAME:Vicki Brown\n',
#  'CITY_ID\n',
#  '2cc8f54182c37b8907f534011ea01e6f\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81519\n',
#  'FACILITY NAME:\n',
#  'Alloa Glass Factory\n',
#  '81520\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000073.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Alloa\n',
#  'EPRTRSectorCode:\n',
#  '3\n',
#  'eprtrSectorName:\n',
#  'Mineral industry\n',
#  'MainActivityCode:3(e)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Nitrogen oxides (NOX)\n',
#  'emissions:\n',
#  '990000\n',
#  'DAY:\n',
#  '28\n',
#  'MONTH:\n',
#  '9 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,74E+16\n',
#  'min_wind_speed:\n',
#  '2,23E+15 avg_wind_speed: 1,89E+16\n',
#  'max_temp:\n',
#  '5,82E+14\n',
#  'min_temp:\n',
#  '9,39E+15 avg_temp:\n',
#  '6,09E+15\n',
#  'DAYS FOG:\n',
#  '12\n',
#  'REPORTER NAME:Lance Hart\n',
#  'CITY_ID\n',
#  '2cc8f54182c37b8907f534011ea01e6f\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81520\n',
#  'FACILITY NAME:\n',
#  'Restenneth Landfill Site, Forfar\n',
#  '81521\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000081.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Forfar\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '694000\n',
#  'DAY:\n',
#  '20\n',
#  'MONTH:\n',
#  '8 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed:\n',
#  '1,2E+16\n',
#  'min_wind_speed:\n',
#  '2,35E+16 avg_wind_speed: 1,61E+16\n',
#  'max_temp:\n',
#  '6,3E+15\n',
#  'min_temp:\n',
#  '1,28E+16 avg_temp:\n',
#  '8,42E+14\n',
#  'DAYS FOG:\n',
#  '3\n',
#  'REPORTER NAME:Timothy Williams\n',
#  'CITY_ID\n',
#  'f66f865a6e8c90a9bcafc9def2e701f5\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81521\n',
#  'FACILITY NAME:\n',
#  'Auchenlosh Landfill Site\n',
#  '81522\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000082.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Dalbeattie\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '101000\n',
#  'DAY:\n',
#  '15\n',
#  'MONTH:\n',
#  '4 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,46E+16\n',
#  'min_wind_speed:\n',
#  '1,7E+16 avg_wind_speed: 1,47E+16\n',
#  'max_temp:\n',
#  '9,74E+15\n',
#  'min_temp:\n',
#  '1,1E+16 avg_temp:\n',
#  '9,23E+15\n',
#  'DAYS FOG:\n',
#  '2\n',
#  'REPORTER NAME:Brian Sims\n',
#  'CITY_ID\n',
#  'd52bec466f0edb76a6fc14c109598ba2\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81522\n',
#  'FACILITY NAME:\n',
#  'Auchencarroch Landfill, Jamestown\n',
#  '81523\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000083.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Alexandria\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '1300000\n',
#  'DAY:\n',
#  '9\n',
#  'MONTH:\n',
#  '11 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,69E+16\n',
#  'min_wind_speed:\n',
#  '2,07E+16 avg_wind_speed: 1,79E+15\n',
#  'max_temp:\n',
#  '5,38E+15\n',
#  'min_temp:\n',
#  '1,18E+15 avg_temp:\n',
#  '7,29E+15\n',
#  'DAYS FOG:\n',
#  '12\n',
#  'REPORTER NAME:Tracy Powell\n',
#  'CITY_ID\n',
#  'a6bc8f85a33112c5beea4d357caad4cd\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81523\n',
#  'FACILITY NAME:\n',
#  'Garlaff Landfill Site, Cumnock\n',
#  '81524\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000084.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Cumnock\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '999000\n',
#  'DAY:\n',
#  '20\n',
#  'MONTH:\n',
#  '11 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,49E+15\n',
#  'min_wind_speed:\n',
#  '2,37E+16 avg_wind_speed: 2,04E+16\n',
#  'max_temp:\n',
#  '1,58E+16\n',
#  'min_temp:\n',
#  '8,9E+15 avg_temp:\n',
#  '4,32E+14\n',
#  'DAYS FOG:\n',
#  '11\n',
#  'REPORTER NAME:Rebecca Brooks\n',
#  'CITY_ID\n',
#  'b6ca640b7121ae2bf206ea088f6a4618\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81524\n',
#  'FACILITY NAME:\n',
#  'Binn Farm Landfill Site\n',
#  '81525\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000085.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Glenfarg\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '196000\n',
#  'DAY:\n',
#  '7\n',
#  'MONTH:\n',
#  '6 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 2,15E+15\n',
#  'min_wind_speed:\n',
#  '2,78E+16 avg_wind_speed: 2,08E+16\n',
#  'max_temp:\n',
#  '1,22E+15\n',
#  'min_temp:\n',
#  '1,58E+16 avg_temp:\n',
#  '1,22E+14\n',
#  'DAYS FOG:\n',
#  '8\n',
#  'REPORTER NAME:Tammy Williams\n',
#  'CITY_ID\n',
#  '930b3f6a2b01ab9967c61d939efce973\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81525\n',
#  'FACILITY NAME:\n',
#  'Kilgarth Landfill, Coatbridge\n',
#  '81526\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000086.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Coatbridge\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '190000\n',
#  'DAY:\n',
#  '21\n',
#  'MONTH:\n',
#  '1 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,71E+16\n',
#  'min_wind_speed:\n',
#  '2,52E+16 avg_wind_speed: 2,14E+16\n',
#  'max_temp:\n',
#  '1,12E+15\n',
#  'min_temp:\n',
#  '1,3E+15 avg_temp:\n',
#  '1,09E+16\n',
#  'DAYS FOG:\n',
#  '17\n',
#  'REPORTER NAME:Lindsey Frazier\n',
#  'CITY_ID\n',
#  '2b83cfb769c8c15a3a0329410129a67f\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81526\n',
#  'FACILITY NAME:\n',
#  'Black Devon Landfill Site, Alloa\n',
#  '81527\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000087.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Alloa, Clackmannanshire\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '107000\n',
#  'DAY:\n',
#  '27\n',
#  'MONTH:\n',
#  '6 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,61E+16\n',
#  'min_wind_speed:\n',
#  '2,41E+16 avg_wind_speed: 1,72E+15\n',
#  'max_temp:\n',
#  '8,75E+15\n',
#  'min_temp:\n',
#  '1,41E+16 avg_temp:\n',
#  '1,03E+16\n',
#  'DAYS FOG:\n',
#  '18\n',
#  'REPORTER NAME:Ryan Russell\n',
#  'CITY_ID\n',
#  '10fac069cd96c396ab2b6998ae548389\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81527\n',
#  'FACILITY NAME:\n',
#  'Bennadrove Landfill Site\n',
#  '81528\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000088.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Isle of Lewis\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '602000\n',
#  'DAY:\n',
#  '18\n',
#  'MONTH:\n',
#  '9 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,79E+15\n',
#  'min_wind_speed:\n',
#  '2,32E+15 avg_wind_speed: 1,84E+16\n',
#  'max_temp:\n',
#  '3,65E+16\n',
#  'min_temp:\n',
#  '8,38E+15 avg_temp:\n',
#  '6,01E+15\n',
#  'DAYS FOG:\n',
#  '6\n',
#  'REPORTER NAME:Ryan Wallace\n',
#  'CITY_ID\n',
#  'c8a033ac7efbddf5c15e8e135fb15f51\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81528\n',
#  'FACILITY NAME:\n',
#  'Lochhead Landfill Site, Drumfermiline\n',
#  '81529\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000094.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Dunfermline\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '1650000\n',
#  'DAY:\n',
#  '26\n',
#  'MONTH:\n',
#  '12 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,84E+15\n',
#  'min_wind_speed:\n',
#  '2,25E+16 avg_wind_speed: 1,99E+16\n',
#  'max_temp:\n',
#  '9,81E+15\n',
#  'min_temp:\n',
#  '1,28E+16 avg_temp:\n',
#  '1,12E+16\n',
#  'DAYS FOG:\n',
#  '2\n',
#  'REPORTER NAME:Julie Shaffer\n',
#  'CITY_ID\n',
#  'ca2df88517d85dbac7129467fbd1effc\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81529\n',
#  'FACILITY NAME:\n',
#  'Lower Melville Wood Landfill, By Ladybank\n',
#  '81530\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000095.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Cupar, Fife\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '602000\n',
#  'DAY:\n',
#  '27\n',
#  'MONTH:\n',
#  '10 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,37E+16\n',
#  'min_wind_speed:\n',
#  '2,25E+16 avg_wind_speed: 1,47E+16\n',
#  'max_temp:\n',
#  '9,6E+15\n',
#  'min_temp:\n',
#  '1,25E+16 avg_temp:\n',
#  '9,19E+15\n',
#  'DAYS FOG:\n',
#  '9\n',
#  'REPORTER NAME:Brenda Holland\n',
#  'CITY_ID\n',
#  'd784f55b1d1ae261dff896b5030ca94e\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81530\n',
#  'FACILITY NAME:\n',
#  'South Cathkin Landfill Site, East Kilbride\n',
#  '81531\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000097.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'East Kilbride\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '1220000\n',
#  'DAY:\n',
#  '22\n',
#  'MONTH:\n',
#  '3 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,42E+15\n',
#  'min_wind_speed:\n',
#  '1,98E+16 avg_wind_speed: 1,63E+16\n',
#  'max_temp:\n',
#  '9,02E+15\n',
#  'min_temp:\n',
#  '1,41E+16 avg_temp:\n',
#  '1,18E+16\n',
#  'DAYS FOG:\n',
#  '3\n',
#  'REPORTER NAME:Shelby Griffin\n',
#  'CITY_ID\n',
#  '18310638e5a7e7efb1b112016920c9f6\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81531\n',
#  'FACILITY NAME:\n',
#  'Summerston Landfill Site, Glasgow\n',
#  '81532\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000098.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Summerston\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '163000\n',
#  'DAY:\n',
#  '9\n',
#  'MONTH:\n',
#  '4 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed:\n',
#  '1,2E+16\n',
#  'min_wind_speed:\n',
#  '1,88E+15 avg_wind_speed: 1,53E+16\n',
#  'max_temp:\n',
#  '6,93E+15\n',
#  'min_temp:\n',
#  '9,22E+15 avg_temp:\n',
#  '7,74E+15\n',
#  'DAYS FOG:\n',
#  '5\n',
#  'REPORTER NAME:Sandra Wyatt\n',
#  'CITY_ID\n',
#  'd90f4f7149ed3e451f4618f82734dae7\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81532\n',
#  'FACILITY NAME:\n',
#  'Battleby Landfill Site, Perth\n',
#  '81533\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000101.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Perth\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(c)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '354000\n',
#  'DAY:\n',
#  '18\n',
#  'MONTH:\n',
#  '7 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,26E+15\n',
#  'min_wind_speed:\n',
#  '2,17E+15 avg_wind_speed: 1,64E+16\n',
#  'max_temp:\n',
#  '1,11E+16\n',
#  'min_temp:\n',
#  '1,5E+16 avg_temp:\n',
#  '1,1E+16\n',
#  'DAYS FOG:\n',
#  '4\n',
#  'REPORTER NAME:Michael Cruz\n',
#  'CITY_ID\n',
#  '4bc44fa25c7afaf63618e6586084052e\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81533\n',
#  'FACILITY NAME:\n',
#  'Kirkhill Landfill Site, Elgin\n',
#  '81534\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000105.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Elgin\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '253000\n',
#  'DAY:\n',
#  '7\n',
#  'MONTH:\n',
#  '5 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 2,05E+16\n',
#  'min_wind_speed:\n',
#  '2,47E+16 avg_wind_speed: 2,04E+14\n',
#  'max_temp:\n',
#  '1,68E+16\n',
#  'min_temp:\n',
#  '1,96E+16 avg_temp:\n',
#  '1,76E+13\n',
#  'DAYS FOG:\n',
#  '8\n',
#  'REPORTER NAME:Ashley Sanders\n',
#  'CITY_ID\n',
#  '16551e9337c69fac02ef95ddc620c8df\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81534\n',
#  'FACILITY NAME:\n',
#  'Nether Dallachy Landfill Site\n',
#  '81535\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000106.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Spey Bay\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '945000\n',
#  'DAY:\n',
#  '1\n',
#  'MONTH:\n',
#  '6 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,64E+16\n',
#  'min_wind_speed:\n',
#  '2,57E+16 avg_wind_speed: 1,82E+15\n',
#  'max_temp:\n',
#  '1,98E+14\n',
#  'min_temp:\n',
#  '2,04E+16 avg_temp:\n',
#  '1,91E+16\n',
#  'DAYS FOG:\n',
#  '7\n',
#  'REPORTER NAME:Emily Martinez\n',
#  'CITY_ID\n',
#  'a05c92d590027b51608394c16aedc477\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81535\n',
#  'FACILITY NAME:\n',
#  'Auchinlea Landfill Site, Motherwell\n',
#  '81536\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000109.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Clelland\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '922000\n',
#  'DAY:\n',
#  '15\n',
#  'MONTH:\n',
#  '2 YEAR:\n',
#  '2019\n',
#  'METEOROLOGICAL CONDITIONS\n',
#  'max_wind_speed: 1,76E+15\n',
#  'min_wind_speed:\n',
#  '2,26E+15 avg_wind_speed: 1,72E+16\n',
#  'max_temp:\n',
#  '1,21E+16\n',
#  'min_temp:\n',
#  '1,66E+16 avg_temp:\n',
#  '1,24E+16\n',
#  'DAYS FOG:\n',
#  '14\n',
#  'REPORTER NAME:Reginald Fisher\n',
#  'CITY_ID\n',
#  '82403770c9ed79e39a23ca735c8d945e\n',
#  '\x0cREPORT CONTAMINACIÓN\n',
#  'nº:\n',
#  '81536\n',
#  'FACILITY NAME:\n',
#  'Greenoakhill Landfill Site, Glasgow\n',
#  '81537\n',
#  'FacilityInspireID:\n',
#  'UK.SEPA/200000110.Facility\n',
#  'COUNTRY:\n',
#  'United Kingdom\n',
#  'CONTINENT:\n',
#  'EUROPE\n',
#  'CITY:\n',
#  'Mount Vernon\n',
#  'EPRTRSectorCode:\n',
#  '5\n',
#  'eprtrSectorName:\n',
#  'Waste and wastewater management\n',
#  'MainActivityCode:5(d)\n',
#  'targetRealase:\n',
#  'AIR\n',
#  'pollutant:\n',
#  'Methane (CH4)\n',
#  'emissions:\n',
#  '1910000\n',
#  'DAY:\n',
#  '14\n',
#  'MONTH:\n',
#  '3 YEAR:\n',
#  '2019\n',
#  ...]

# %% [markdown]
# Splitting to form column name and its values :

# %%
cont=[]
for i in range(0,len(all_annots)):
    cont.append(all_annots[i].split(' ',0))

# %%
cont
# Out:
# [['REPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81597\n'],
#  ['FACILITY NAME:\n'],
#  ['Millerhill Recycling & Energy Recovery Centre\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200002651.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Millerhill, Dalkeith\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(b)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Nitrogen oxides (NOX)\n'],
#  ['emissions:\n'],
#  ['175000\n'],
#  ['DAY:\n'],
#  ['12\n'],
#  ['MONTH:\n'],
#  ['6 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,79E+15\n'],
#  ['min_wind_speed:\n'],
#  ['2,2E+16 avg_wind_speed: 2,04E+15\n'],
#  ['max_temp:\n'],
#  ['1,51E+16\n'],
#  ['min_temp:\n'],
#  ['1,82E+15 avg_temp:\n'],
#  ['1,71E+16\n'],
#  ['DAYS FOG:\n'],
#  ['10\n'],
#  ['REPORTER NAME:William Nelson\n'],
#  ['CITY_ID\n'],
#  ['c662b4b4d859a9c224b5ac0acf221748\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81516\n'],
#  ['FACILITY NAME:\n'],
#  ['Fife Ethylene Plant\n'],
#  ['81516\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000061.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Cowdenbeath\n'],
#  ['EPRTRSectorCode:\n'],
#  ['1\n'],
#  ['eprtrSectorName:\n'],
#  ['Energy sector\n'],
#  ['MainActivityCode:1(c)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Carbon dioxide (CO2)\n'],
#  ['emissions:\n'],
#  ['6,8E+08\n'],
#  ['DAY:\n'],
#  ['12\n'],
#  ['MONTH:\n'],
#  ['4 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,52E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,06E+15 avg_wind_speed: 1,46E+16\n'],
#  ['max_temp:\n'],
#  ['9,61E+15\n'],
#  ['min_temp:\n'],
#  ['1,33E+16 avg_temp:\n'],
#  ['8,69E+15\n'],
#  ['DAYS FOG:\n'],
#  ['19\n'],
#  ['REPORTER NAME:Shawn Graham\n'],
#  ['CITY_ID\n'],
#  ['3c563ab0d76fc84128574b5da82f769a\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81516\n'],
#  ['FACILITY NAME:\n'],
#  ['Fife Ethylene Plant\n'],
#  ['81517\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000061.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Cowdenbeath\n'],
#  ['EPRTRSectorCode:\n'],
#  ['1\n'],
#  ['eprtrSectorName:\n'],
#  ['Energy sector\n'],
#  ['MainActivityCode:1(c)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Carbon dioxide (CO2)\n'],
#  ['emissions:\n'],
#  ['6,8E+08\n'],
#  ['DAY:\n'],
#  ['12\n'],
#  ['MONTH:\n'],
#  ['4 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,52E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,06E+15 avg_wind_speed: 1,46E+16\n'],
#  ['max_temp:\n'],
#  ['9,61E+15\n'],
#  ['min_temp:\n'],
#  ['1,33E+16 avg_temp:\n'],
#  ['8,69E+15\n'],
#  ['DAYS FOG:\n'],
#  ['19\n'],
#  ['REPORTER NAME:Shawn Graham\n'],
#  ['CITY_ID\n'],
#  ['3c563ab0d76fc84128574b5da82f769a\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81517\n'],
#  ['FACILITY NAME:\n'],
#  ['Fife Ethylene Plant\n'],
#  ['81518\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000061.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Cowdenbeath\n'],
#  ['EPRTRSectorCode:\n'],
#  ['1\n'],
#  ['eprtrSectorName:\n'],
#  ['Energy sector\n'],
#  ['MainActivityCode:1(c)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Nitrogen oxides (NOX)\n'],
#  ['emissions:\n'],
#  ['633000\n'],
#  ['DAY:\n'],
#  ['3\n'],
#  ['MONTH:\n'],
#  ['1 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,16E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,18E+16 avg_wind_speed: 1,65E+16\n'],
#  ['max_temp:\n'],
#  ['8,03E+15\n'],
#  ['min_temp:\n'],
#  ['1,04E+16 avg_temp:\n'],
#  ['8,94E+15\n'],
#  ['DAYS FOG:\n'],
#  ['10\n'],
#  ['REPORTER NAME:Aaron Johnson\n'],
#  ['CITY_ID\n'],
#  ['3c563ab0d76fc84128574b5da82f769a\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81518\n'],
#  ['FACILITY NAME:\n'],
#  ['Alloa Glass Factory\n'],
#  ['81519\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000073.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Alloa\n'],
#  ['EPRTRSectorCode:\n'],
#  ['3\n'],
#  ['eprtrSectorName:\n'],
#  ['Mineral industry\n'],
#  ['MainActivityCode:3(e)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Carbon dioxide (CO2)\n'],
#  ['emissions:\n'],
#  ['1,49E+08\n'],
#  ['DAY:\n'],
#  ['9\n'],
#  ['MONTH:\n'],
#  ['11 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,11E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,03E+16 avg_wind_speed:\n'],
#  ['1,6E+16\n'],
#  ['max_temp:\n'],
#  ['-1,9E+16\n'],
#  ['min_temp:\n'],
#  ['4,07E+16 avg_temp:\n'],
#  ['1,33E+15\n'],
#  ['DAYS FOG:\n'],
#  ['4\n'],
#  ['REPORTER NAME:Vicki Brown\n'],
#  ['CITY_ID\n'],
#  ['2cc8f54182c37b8907f534011ea01e6f\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81519\n'],
#  ['FACILITY NAME:\n'],
#  ['Alloa Glass Factory\n'],
#  ['81520\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000073.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Alloa\n'],
#  ['EPRTRSectorCode:\n'],
#  ['3\n'],
#  ['eprtrSectorName:\n'],
#  ['Mineral industry\n'],
#  ['MainActivityCode:3(e)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Nitrogen oxides (NOX)\n'],
#  ['emissions:\n'],
#  ['990000\n'],
#  ['DAY:\n'],
#  ['28\n'],
#  ['MONTH:\n'],
#  ['9 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,74E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,23E+15 avg_wind_speed: 1,89E+16\n'],
#  ['max_temp:\n'],
#  ['5,82E+14\n'],
#  ['min_temp:\n'],
#  ['9,39E+15 avg_temp:\n'],
#  ['6,09E+15\n'],
#  ['DAYS FOG:\n'],
#  ['12\n'],
#  ['REPORTER NAME:Lance Hart\n'],
#  ['CITY_ID\n'],
#  ['2cc8f54182c37b8907f534011ea01e6f\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81520\n'],
#  ['FACILITY NAME:\n'],
#  ['Restenneth Landfill Site, Forfar\n'],
#  ['81521\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000081.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Forfar\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['694000\n'],
#  ['DAY:\n'],
#  ['20\n'],
#  ['MONTH:\n'],
#  ['8 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed:\n'],
#  ['1,2E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,35E+16 avg_wind_speed: 1,61E+16\n'],
#  ['max_temp:\n'],
#  ['6,3E+15\n'],
#  ['min_temp:\n'],
#  ['1,28E+16 avg_temp:\n'],
#  ['8,42E+14\n'],
#  ['DAYS FOG:\n'],
#  ['3\n'],
#  ['REPORTER NAME:Timothy Williams\n'],
#  ['CITY_ID\n'],
#  ['f66f865a6e8c90a9bcafc9def2e701f5\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81521\n'],
#  ['FACILITY NAME:\n'],
#  ['Auchenlosh Landfill Site\n'],
#  ['81522\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000082.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Dalbeattie\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['101000\n'],
#  ['DAY:\n'],
#  ['15\n'],
#  ['MONTH:\n'],
#  ['4 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,46E+16\n'],
#  ['min_wind_speed:\n'],
#  ['1,7E+16 avg_wind_speed: 1,47E+16\n'],
#  ['max_temp:\n'],
#  ['9,74E+15\n'],
#  ['min_temp:\n'],
#  ['1,1E+16 avg_temp:\n'],
#  ['9,23E+15\n'],
#  ['DAYS FOG:\n'],
#  ['2\n'],
#  ['REPORTER NAME:Brian Sims\n'],
#  ['CITY_ID\n'],
#  ['d52bec466f0edb76a6fc14c109598ba2\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81522\n'],
#  ['FACILITY NAME:\n'],
#  ['Auchencarroch Landfill, Jamestown\n'],
#  ['81523\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000083.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Alexandria\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['1300000\n'],
#  ['DAY:\n'],
#  ['9\n'],
#  ['MONTH:\n'],
#  ['11 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,69E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,07E+16 avg_wind_speed: 1,79E+15\n'],
#  ['max_temp:\n'],
#  ['5,38E+15\n'],
#  ['min_temp:\n'],
#  ['1,18E+15 avg_temp:\n'],
#  ['7,29E+15\n'],
#  ['DAYS FOG:\n'],
#  ['12\n'],
#  ['REPORTER NAME:Tracy Powell\n'],
#  ['CITY_ID\n'],
#  ['a6bc8f85a33112c5beea4d357caad4cd\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81523\n'],
#  ['FACILITY NAME:\n'],
#  ['Garlaff Landfill Site, Cumnock\n'],
#  ['81524\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000084.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Cumnock\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['999000\n'],
#  ['DAY:\n'],
#  ['20\n'],
#  ['MONTH:\n'],
#  ['11 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,49E+15\n'],
#  ['min_wind_speed:\n'],
#  ['2,37E+16 avg_wind_speed: 2,04E+16\n'],
#  ['max_temp:\n'],
#  ['1,58E+16\n'],
#  ['min_temp:\n'],
#  ['8,9E+15 avg_temp:\n'],
#  ['4,32E+14\n'],
#  ['DAYS FOG:\n'],
#  ['11\n'],
#  ['REPORTER NAME:Rebecca Brooks\n'],
#  ['CITY_ID\n'],
#  ['b6ca640b7121ae2bf206ea088f6a4618\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81524\n'],
#  ['FACILITY NAME:\n'],
#  ['Binn Farm Landfill Site\n'],
#  ['81525\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000085.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Glenfarg\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['196000\n'],
#  ['DAY:\n'],
#  ['7\n'],
#  ['MONTH:\n'],
#  ['6 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 2,15E+15\n'],
#  ['min_wind_speed:\n'],
#  ['2,78E+16 avg_wind_speed: 2,08E+16\n'],
#  ['max_temp:\n'],
#  ['1,22E+15\n'],
#  ['min_temp:\n'],
#  ['1,58E+16 avg_temp:\n'],
#  ['1,22E+14\n'],
#  ['DAYS FOG:\n'],
#  ['8\n'],
#  ['REPORTER NAME:Tammy Williams\n'],
#  ['CITY_ID\n'],
#  ['930b3f6a2b01ab9967c61d939efce973\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81525\n'],
#  ['FACILITY NAME:\n'],
#  ['Kilgarth Landfill, Coatbridge\n'],
#  ['81526\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000086.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Coatbridge\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['190000\n'],
#  ['DAY:\n'],
#  ['21\n'],
#  ['MONTH:\n'],
#  ['1 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,71E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,52E+16 avg_wind_speed: 2,14E+16\n'],
#  ['max_temp:\n'],
#  ['1,12E+15\n'],
#  ['min_temp:\n'],
#  ['1,3E+15 avg_temp:\n'],
#  ['1,09E+16\n'],
#  ['DAYS FOG:\n'],
#  ['17\n'],
#  ['REPORTER NAME:Lindsey Frazier\n'],
#  ['CITY_ID\n'],
#  ['2b83cfb769c8c15a3a0329410129a67f\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81526\n'],
#  ['FACILITY NAME:\n'],
#  ['Black Devon Landfill Site, Alloa\n'],
#  ['81527\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000087.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Alloa, Clackmannanshire\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['107000\n'],
#  ['DAY:\n'],
#  ['27\n'],
#  ['MONTH:\n'],
#  ['6 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,61E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,41E+16 avg_wind_speed: 1,72E+15\n'],
#  ['max_temp:\n'],
#  ['8,75E+15\n'],
#  ['min_temp:\n'],
#  ['1,41E+16 avg_temp:\n'],
#  ['1,03E+16\n'],
#  ['DAYS FOG:\n'],
#  ['18\n'],
#  ['REPORTER NAME:Ryan Russell\n'],
#  ['CITY_ID\n'],
#  ['10fac069cd96c396ab2b6998ae548389\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81527\n'],
#  ['FACILITY NAME:\n'],
#  ['Bennadrove Landfill Site\n'],
#  ['81528\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000088.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Isle of Lewis\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['602000\n'],
#  ['DAY:\n'],
#  ['18\n'],
#  ['MONTH:\n'],
#  ['9 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,79E+15\n'],
#  ['min_wind_speed:\n'],
#  ['2,32E+15 avg_wind_speed: 1,84E+16\n'],
#  ['max_temp:\n'],
#  ['3,65E+16\n'],
#  ['min_temp:\n'],
#  ['8,38E+15 avg_temp:\n'],
#  ['6,01E+15\n'],
#  ['DAYS FOG:\n'],
#  ['6\n'],
#  ['REPORTER NAME:Ryan Wallace\n'],
#  ['CITY_ID\n'],
#  ['c8a033ac7efbddf5c15e8e135fb15f51\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81528\n'],
#  ['FACILITY NAME:\n'],
#  ['Lochhead Landfill Site, Drumfermiline\n'],
#  ['81529\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000094.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Dunfermline\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['1650000\n'],
#  ['DAY:\n'],
#  ['26\n'],
#  ['MONTH:\n'],
#  ['12 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,84E+15\n'],
#  ['min_wind_speed:\n'],
#  ['2,25E+16 avg_wind_speed: 1,99E+16\n'],
#  ['max_temp:\n'],
#  ['9,81E+15\n'],
#  ['min_temp:\n'],
#  ['1,28E+16 avg_temp:\n'],
#  ['1,12E+16\n'],
#  ['DAYS FOG:\n'],
#  ['2\n'],
#  ['REPORTER NAME:Julie Shaffer\n'],
#  ['CITY_ID\n'],
#  ['ca2df88517d85dbac7129467fbd1effc\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81529\n'],
#  ['FACILITY NAME:\n'],
#  ['Lower Melville Wood Landfill, By Ladybank\n'],
#  ['81530\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000095.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Cupar, Fife\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['602000\n'],
#  ['DAY:\n'],
#  ['27\n'],
#  ['MONTH:\n'],
#  ['10 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,37E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,25E+16 avg_wind_speed: 1,47E+16\n'],
#  ['max_temp:\n'],
#  ['9,6E+15\n'],
#  ['min_temp:\n'],
#  ['1,25E+16 avg_temp:\n'],
#  ['9,19E+15\n'],
#  ['DAYS FOG:\n'],
#  ['9\n'],
#  ['REPORTER NAME:Brenda Holland\n'],
#  ['CITY_ID\n'],
#  ['d784f55b1d1ae261dff896b5030ca94e\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81530\n'],
#  ['FACILITY NAME:\n'],
#  ['South Cathkin Landfill Site, East Kilbride\n'],
#  ['81531\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000097.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['East Kilbride\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['1220000\n'],
#  ['DAY:\n'],
#  ['22\n'],
#  ['MONTH:\n'],
#  ['3 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,42E+15\n'],
#  ['min_wind_speed:\n'],
#  ['1,98E+16 avg_wind_speed: 1,63E+16\n'],
#  ['max_temp:\n'],
#  ['9,02E+15\n'],
#  ['min_temp:\n'],
#  ['1,41E+16 avg_temp:\n'],
#  ['1,18E+16\n'],
#  ['DAYS FOG:\n'],
#  ['3\n'],
#  ['REPORTER NAME:Shelby Griffin\n'],
#  ['CITY_ID\n'],
#  ['18310638e5a7e7efb1b112016920c9f6\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81531\n'],
#  ['FACILITY NAME:\n'],
#  ['Summerston Landfill Site, Glasgow\n'],
#  ['81532\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000098.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Summerston\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['163000\n'],
#  ['DAY:\n'],
#  ['9\n'],
#  ['MONTH:\n'],
#  ['4 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed:\n'],
#  ['1,2E+16\n'],
#  ['min_wind_speed:\n'],
#  ['1,88E+15 avg_wind_speed: 1,53E+16\n'],
#  ['max_temp:\n'],
#  ['6,93E+15\n'],
#  ['min_temp:\n'],
#  ['9,22E+15 avg_temp:\n'],
#  ['7,74E+15\n'],
#  ['DAYS FOG:\n'],
#  ['5\n'],
#  ['REPORTER NAME:Sandra Wyatt\n'],
#  ['CITY_ID\n'],
#  ['d90f4f7149ed3e451f4618f82734dae7\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81532\n'],
#  ['FACILITY NAME:\n'],
#  ['Battleby Landfill Site, Perth\n'],
#  ['81533\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000101.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Perth\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(c)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['354000\n'],
#  ['DAY:\n'],
#  ['18\n'],
#  ['MONTH:\n'],
#  ['7 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,26E+15\n'],
#  ['min_wind_speed:\n'],
#  ['2,17E+15 avg_wind_speed: 1,64E+16\n'],
#  ['max_temp:\n'],
#  ['1,11E+16\n'],
#  ['min_temp:\n'],
#  ['1,5E+16 avg_temp:\n'],
#  ['1,1E+16\n'],
#  ['DAYS FOG:\n'],
#  ['4\n'],
#  ['REPORTER NAME:Michael Cruz\n'],
#  ['CITY_ID\n'],
#  ['4bc44fa25c7afaf63618e6586084052e\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81533\n'],
#  ['FACILITY NAME:\n'],
#  ['Kirkhill Landfill Site, Elgin\n'],
#  ['81534\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000105.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Elgin\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['253000\n'],
#  ['DAY:\n'],
#  ['7\n'],
#  ['MONTH:\n'],
#  ['5 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 2,05E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,47E+16 avg_wind_speed: 2,04E+14\n'],
#  ['max_temp:\n'],
#  ['1,68E+16\n'],
#  ['min_temp:\n'],
#  ['1,96E+16 avg_temp:\n'],
#  ['1,76E+13\n'],
#  ['DAYS FOG:\n'],
#  ['8\n'],
#  ['REPORTER NAME:Ashley Sanders\n'],
#  ['CITY_ID\n'],
#  ['16551e9337c69fac02ef95ddc620c8df\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81534\n'],
#  ['FACILITY NAME:\n'],
#  ['Nether Dallachy Landfill Site\n'],
#  ['81535\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000106.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Spey Bay\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['945000\n'],
#  ['DAY:\n'],
#  ['1\n'],
#  ['MONTH:\n'],
#  ['6 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,64E+16\n'],
#  ['min_wind_speed:\n'],
#  ['2,57E+16 avg_wind_speed: 1,82E+15\n'],
#  ['max_temp:\n'],
#  ['1,98E+14\n'],
#  ['min_temp:\n'],
#  ['2,04E+16 avg_temp:\n'],
#  ['1,91E+16\n'],
#  ['DAYS FOG:\n'],
#  ['7\n'],
#  ['REPORTER NAME:Emily Martinez\n'],
#  ['CITY_ID\n'],
#  ['a05c92d590027b51608394c16aedc477\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81535\n'],
#  ['FACILITY NAME:\n'],
#  ['Auchinlea Landfill Site, Motherwell\n'],
#  ['81536\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000109.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Clelland\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['922000\n'],
#  ['DAY:\n'],
#  ['15\n'],
#  ['MONTH:\n'],
#  ['2 YEAR:\n'],
#  ['2019\n'],
#  ['METEOROLOGICAL CONDITIONS\n'],
#  ['max_wind_speed: 1,76E+15\n'],
#  ['min_wind_speed:\n'],
#  ['2,26E+15 avg_wind_speed: 1,72E+16\n'],
#  ['max_temp:\n'],
#  ['1,21E+16\n'],
#  ['min_temp:\n'],
#  ['1,66E+16 avg_temp:\n'],
#  ['1,24E+16\n'],
#  ['DAYS FOG:\n'],
#  ['14\n'],
#  ['REPORTER NAME:Reginald Fisher\n'],
#  ['CITY_ID\n'],
#  ['82403770c9ed79e39a23ca735c8d945e\n'],
#  ['\x0cREPORT CONTAMINACIÓN\n'],
#  ['nº:\n'],
#  ['81536\n'],
#  ['FACILITY NAME:\n'],
#  ['Greenoakhill Landfill Site, Glasgow\n'],
#  ['81537\n'],
#  ['FacilityInspireID:\n'],
#  ['UK.SEPA/200000110.Facility\n'],
#  ['COUNTRY:\n'],
#  ['United Kingdom\n'],
#  ['CONTINENT:\n'],
#  ['EUROPE\n'],
#  ['CITY:\n'],
#  ['Mount Vernon\n'],
#  ['EPRTRSectorCode:\n'],
#  ['5\n'],
#  ['eprtrSectorName:\n'],
#  ['Waste and wastewater management\n'],
#  ['MainActivityCode:5(d)\n'],
#  ['targetRealase:\n'],
#  ['AIR\n'],
#  ['pollutant:\n'],
#  ['Methane (CH4)\n'],
#  ['emissions:\n'],
#  ['1910000\n'],
#  ['DAY:\n'],
#  ['14\n'],
#  ['MONTH:\n'],
#  ['3 YEAR:\n'],
#  ['2019\n'],
#  ...]

# %%
liss=[]
for i in range(0,len(cont)):
    lis=[]
    for j in cont[i]:
        j=j.replace('*','')
        j=j.replace('#','')
        j=j.replace(':','')
        j=j.replace('\n','') 
        j=j.strip()
        #print(j)
        lis.append(j)
    liss.append(lis)

# %%
features = ['FACILITY NAME', 'FacilityInspireID', 'COUNTRY', 'CONTINENT', 'CITY', 'EPRTRSectorCode', 'eprtrSectorName','MainActivityCode','emissions','DAY','MONTH','YEAR','max_wind_speed','min_wind_speed','avg_wind_speed ','max_temp','min_temp','avg_temp','DAYS FOG','CITY_ID', 'pollutant']

# %%
data_pdf_df = pd.DataFrame(columns=features)

# %%
for i in features:
    cont = 0
    for j in range(0,len(liss)):
        if i == liss[j][0]:
            cont = cont + 1
            if len(liss[j+1][0].split(' ')) > 2 and (i != 'FACILITY NAME'):
                parcial=[]
                for k in range(len(liss[j+1][0].split(' '))):
                        parcial = liss[j+1][0].split(' ')
                        index = features.index(i)
                        data_pdf_df.loc[cont,features[index]] = parcial[k]
                        index = index +1
            else:
                data_pdf_df.loc[cont,i] = liss[j+1][0]

# %%
data_pdf_df.head(10)
# Out:
#                                     FACILITY NAME           FacilityInspireID  \
# 1   Millerhill Recycling & Energy Recovery Centre  UK.SEPA/200002651.Facility
# 2                             Fife Ethylene Plant  UK.SEPA/200000061.Facility
# 3                             Fife Ethylene Plant  UK.SEPA/200000061.Facility
# 4                             Fife Ethylene Plant  UK.SEPA/200000061.Facility
# 5                             Alloa Glass Factory  UK.SEPA/200000073.Facility
# 6                             Alloa Glass Factory  UK.SEPA/200000073.Facility
# 7                Restenneth Landfill Site, Forfar  UK.SEPA/200000081.Facility
# 8                        Auchenlosh Landfill Site  UK.SEPA/200000082.Facility
# 9               Auchencarroch Landfill, Jamestown  UK.SEPA/200000083.Facility
# 10                 Garlaff Landfill Site, Cumnock  UK.SEPA/200000084.Facility
#
#            COUNTRY CONTINENT                  CITY EPRTRSectorCode  \
# 1   United Kingdom    EUROPE  Millerhill, Dalkeith               5
# 2   United Kingdom    EUROPE           Cowdenbeath               1
# 3   United Kingdom    EUROPE           Cowdenbeath               1
# 4   United Kingdom    EUROPE           Cowdenbeath               1
# 5   United Kingdom    EUROPE                 Alloa               3
# 6   United Kingdom    EUROPE                 Alloa               3
# 7   United Kingdom    EUROPE                Forfar               5
# 8   United Kingdom    EUROPE            Dalbeattie               5
# 9   United Kingdom    EUROPE            Alexandria               5
# 10  United Kingdom    EUROPE               Cumnock               5
#
#      eprtrSectorName MainActivityCode emissions DAY  ... YEAR max_wind_speed  \
# 1         management              NaN    175000  12  ...  NaN        1,2E+16
# 2      Energy sector              NaN   6,8E+08  12  ...  NaN        1,2E+16
# 3      Energy sector              NaN   6,8E+08  12  ...  NaN        1,4E+16
# 4      Energy sector              NaN    633000   3  ...  NaN        1,6E+16
# 5   Mineral industry              NaN  1,49E+08   9  ...  NaN        1,6E+16
# 6   Mineral industry              NaN    990000  28  ...  NaN            NaN
# 7         management              NaN    694000  20  ...  NaN            NaN
# 8         management              NaN    101000  15  ...  NaN            NaN
# 9         management              NaN   1300000   9  ...  NaN            NaN
# 10        management              NaN    999000  20  ...  NaN            NaN
#
#              min_wind_speed avg_wind_speed   max_temp           min_temp  \
# 1                  2,04E+15             NaN  1,51E+16  1,82E+15 avg_temp
# 2                  1,46E+16             NaN  9,61E+15  1,33E+16 avg_temp
# 3                  1,46E+16             NaN  9,61E+15  1,33E+16 avg_temp
# 4                  1,65E+16             NaN  8,03E+15  1,04E+16 avg_temp
# 5   2,03E+16 avg_wind_speed             NaN  -1,9E+16  4,07E+16 avg_temp
# 6                  1,89E+16             NaN  5,82E+14  9,39E+15 avg_temp
# 7                  1,61E+16             NaN   6,3E+15  1,28E+16 avg_temp
# 8                  1,47E+16             NaN  9,74E+15   1,1E+16 avg_temp
# 9                  1,79E+15             NaN  5,38E+15  1,18E+15 avg_temp
# 10                 2,04E+16             NaN  1,58E+16   8,9E+15 avg_temp
#
#    avg_temp DAYS FOG                           CITY_ID      pollutant
# 1       NaN       10  c662b4b4d859a9c224b5ac0acf221748          (NOX)
# 2       NaN       19  3c563ab0d76fc84128574b5da82f769a          (CO2)
# 3       NaN       19  3c563ab0d76fc84128574b5da82f769a          (CO2)
# 4       NaN       10  3c563ab0d76fc84128574b5da82f769a          (NOX)
# 5       NaN        4  2cc8f54182c37b8907f534011ea01e6f          (CO2)
# 6       NaN       12  2cc8f54182c37b8907f534011ea01e6f          (NOX)
# 7       NaN        3  f66f865a6e8c90a9bcafc9def2e701f5  Methane (CH4)
# 8       NaN        2  d52bec466f0edb76a6fc14c109598ba2  Methane (CH4)
# 9       NaN       12  a6bc8f85a33112c5beea4d357caad4cd  Methane (CH4)
# 10      NaN       11  b6ca640b7121ae2bf206ea088f6a4618  Methane (CH4)
#
# [10 rows x 21 columns]

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ## ✅  3) Adapting information, identifying and correcting anomalies 🔧
# First, we have to merge all the datasets into one, so that we have a single package to analyze.

# %% [markdown]
# ### **<span style="color:#43A047;">3.0 Checking column orders and differences in data sizes. </span>**

# %%
sizes = [["1st csv", data1_csv_df.shape],
         ["2nd csv", data2_csv_df.shape],
         ["1st json", data1_js_df.shape],
         ["2nd json", data2_js_df.shape],
         ["3th json", data3_js_df.shape],
         ["All pdf", data_pdf_df.shape]]

print("The sizes are %s" %sizes)
# Out:
# The sizes are [['1st csv', (18563, 21)], ['2nd csv', (9500, 25)], ['1st json', (9500, 24)], ['2nd json', (9500, 24)], ['3th json', (9501, 24)], ['All pdf', (82, 21)]]

# %%
sizes
# Out:
# [['1st csv', (18563, 21)],
#  ['2nd csv', (9500, 25)],
#  ['1st json', (9500, 24)],
#  ['2nd json', (9500, 24)],
#  ['3th json', (9501, 24)],
#  ['All pdf', (82, 21)]]

# %% [markdown]
# If there is a difference in columns sizes, the differents columns should be displayed and determine what to do if it is vital information. You can either add a mean to the missing data or delete the extra columns.

# %%
columns = [["1st csv", data1_csv_df.columns.values],
         ["2nd csv", data2_csv_df.columns.values],
         ["1st json", data1_js_df.columns.values],
         ["2nd json", data2_js_df.columns.values],
         ["3th json", data3_js_df.columns.values],
         ["All pdf", data_pdf_df.columns.values]]
print("The order of the columns is:")
columns
# Out:
# The order of the columns is:
# [['1st csv',
#   array(['countryName', 'eprtrSectorName', 'EPRTRAnnexIMainActivityLabel',
#          'FacilityInspireID', 'facilityName', 'City', 'targetRelease',
#          'pollutant', 'reportingYear', 'MONTH', 'DAY', 'CONTINENT',
#          'max_wind_speed', 'avg_wind_speed', 'min_wind_speed', 'max_temp',
#          'avg_temp', 'min_temp', 'DAY WITH FOGS', 'REPORTER NAME',
#          'CITY ID'], dtype=object)],
#  ['2nd csv',
#   array(['Unnamed: 0', 'Unnamed: 1', 'CITY ID', 'CONTINENT', 'City', 'DAY',
#          'DAY WITH FOGS', 'EPRTRAnnexIMainActivityCode',
#          'EPRTRAnnexIMainActivityLabel', 'EPRTRSectorCode',
#          'FacilityInspireID', 'MONTH', 'REPORTER NAME', 'avg_temp',
#          'avg_wind_speed', 'countryName', 'eprtrSectorName', 'facilityName',
#          'max_temp', 'max_wind_speed', 'min_temp', 'min_wind_speed',
#          'pollutant', 'reportingYear', 'targetRelease'], dtype=object)],
#  ['1st json',
#   array(['', 'CITY ID', 'CONTINENT', 'City', 'DAY', 'DAY WITH FOGS',
#          'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel',
#          'EPRTRSectorCode', 'FacilityInspireID', 'MONTH', 'REPORTER NAME',
#          'avg_temp', 'avg_wind_speed', 'countryName', 'eprtrSectorName',
#          'facilityName', 'max_temp', 'max_wind_speed', 'min_temp',
#          'min_wind_speed', 'pollutant', 'reportingYear', 'targetRelease'],
#         dtype=object)],
#  ['2nd json',
#   array(['', 'CITY ID', 'CONTINENT', 'City', 'DAY', 'DAY WITH FOGS',
#          'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel',
#          'EPRTRSectorCode', 'FacilityInspireID', 'MONTH', 'REPORTER NAME',
#          'avg_temp', 'avg_wind_speed', 'countryName', 'eprtrSectorName',
#          'facilityName', 'max_temp', 'max_wind_speed', 'min_temp',
#          'min_wind_speed', 'pollutant', 'reportingYear', 'targetRelease'],
#         dtype=object)],
#  ['3th json',
#   array(['', 'CITY ID', 'CONTINENT', 'City', 'DAY', 'DAY WITH FOGS',
#          'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel',
#          'EPRTRSectorCode', 'FacilityInspireID', 'MONTH', 'REPORTER NAME',
#          'avg_temp', 'avg_wind_speed', 'countryName', 'eprtrSectorName',
#          'facilityName', 'max_temp', 'max_wind_speed', 'min_temp',
#          'min_wind_speed', 'pollutant', 'reportingYear', 'targetRelease'],
#         dtype=object)],
#  ['All pdf',
#   array(['FACILITY NAME', 'FacilityInspireID', 'COUNTRY', 'CONTINENT',
#          'CITY', 'EPRTRSectorCode', 'eprtrSectorName', 'MainActivityCode',
#          'emissions', 'DAY', 'MONTH', 'YEAR', 'max_wind_speed',
#          'min_wind_speed', 'avg_wind_speed ', 'max_temp', 'min_temp',
#          'avg_temp', 'DAYS FOG', 'CITY_ID', 'pollutant'], dtype=object)]]

# %%
def search_diferences(list1, list2, list3, list4, list5, list6):
    cont1=0
    cont2=0
    for i in list1, list2, list3, list4, list5, list6:
        cont1 = cont1+ + 1
        for j in list1, list2, list3, list4, list5, list6:
            cont2 =  cont2 + 1          
            temp = [x for x in i if x not in j]
            print("The diferences between List %s and List %s is \n %s" %(cont1,cont2,temp))
        cont2 = 0

# %%
col1 = data1_csv_df.columns.values
col2 = data2_csv_df.columns.values
col3 = data1_js_df.columns.values
col4 = data2_js_df.columns.values
col5 = data3_js_df.columns.values
col6 = data_pdf_df.columns.values

# %%
search_diferences(col1, col2, col3, col4, col5, col6)
# Out:
# The diferences between List 1 and List 1 is
#  []
# The diferences between List 1 and List 2 is
#  []
# The diferences between List 1 and List 3 is
#  []
# The diferences between List 1 and List 4 is
#  []
# The diferences between List 1 and List 5 is
#  []
# The diferences between List 1 and List 6 is
#  ['countryName', 'EPRTRAnnexIMainActivityLabel', 'facilityName', 'City', 'targetRelease', 'reportingYear', 'avg_wind_speed', 'DAY WITH FOGS', 'REPORTER NAME', 'CITY ID']
# The diferences between List 2 and List 1 is
#  ['Unnamed: 0', 'Unnamed: 1', 'EPRTRAnnexIMainActivityCode', 'EPRTRSectorCode']
# The diferences between List 2 and List 2 is
#  []
# The diferences between List 2 and List 3 is
#  ['Unnamed: 0', 'Unnamed: 1']
# The diferences between List 2 and List 4 is
#  ['Unnamed: 0', 'Unnamed: 1']
# The diferences between List 2 and List 5 is
#  ['Unnamed: 0', 'Unnamed: 1']
# The diferences between List 2 and List 6 is
#  ['Unnamed: 0', 'Unnamed: 1', 'CITY ID', 'City', 'DAY WITH FOGS', 'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel', 'REPORTER NAME', 'avg_wind_speed', 'countryName', 'facilityName', 'reportingYear', 'targetRelease']
# The diferences between List 3 and List 1 is
#  ['', 'EPRTRAnnexIMainActivityCode', 'EPRTRSectorCode']
# The diferences between List 3 and List 2 is
#  ['']
# The diferences between List 3 and List 3 is
#  []
# The diferences between List 3 and List 4 is
#  []
# The diferences between List 3 and List 5 is
#  []
# The diferences between List 3 and List 6 is
#  ['', 'CITY ID', 'City', 'DAY WITH FOGS', 'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel', 'REPORTER NAME', 'avg_wind_speed', 'countryName', 'facilityName', 'reportingYear', 'targetRelease']
# The diferences between List 4 and List 1 is
#  ['', 'EPRTRAnnexIMainActivityCode', 'EPRTRSectorCode']
# The diferences between List 4 and List 2 is
#  ['']
# The diferences between List 4 and List 3 is
#  []
# The diferences between List 4 and List 4 is
#  []
# The diferences between List 4 and List 5 is
#  []
# The diferences between List 4 and List 6 is
#  ['', 'CITY ID', 'City', 'DAY WITH FOGS', 'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel', 'REPORTER NAME', 'avg_wind_speed', 'countryName', 'facilityName', 'reportingYear', 'targetRelease']
# The diferences between List 5 and List 1 is
#  ['', 'EPRTRAnnexIMainActivityCode', 'EPRTRSectorCode']
# The diferences between List 5 and List 2 is
#  ['']
# The diferences between List 5 and List 3 is
#  []
# The diferences between List 5 and List 4 is
#  []
# The diferences between List 5 and List 5 is
#  []
# The diferences between List 5 and List 6 is
#  ['', 'CITY ID', 'City', 'DAY WITH FOGS', 'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel', 'REPORTER NAME', 'avg_wind_speed', 'countryName', 'facilityName', 'reportingYear', 'targetRelease']
# The diferences between List 6 and List 1 is
#  ['FACILITY NAME', 'COUNTRY', 'CITY', 'EPRTRSectorCode', 'MainActivityCode', 'emissions', 'YEAR', 'avg_wind_speed ', 'DAYS FOG', 'CITY_ID']
# The diferences between List 6 and List 2 is
#  ['FACILITY NAME', 'COUNTRY', 'CITY', 'MainActivityCode', 'emissions', 'YEAR', 'avg_wind_speed ', 'DAYS FOG', 'CITY_ID']
# The diferences between List 6 and List 3 is
#  ['FACILITY NAME', 'COUNTRY', 'CITY', 'MainActivityCode', 'emissions', 'YEAR', 'avg_wind_speed ', 'DAYS FOG', 'CITY_ID']
# The diferences between List 6 and List 4 is
#  ['FACILITY NAME', 'COUNTRY', 'CITY', 'MainActivityCode', 'emissions', 'YEAR', 'avg_wind_speed ', 'DAYS FOG', 'CITY_ID']
# The diferences between List 6 and List 5 is
#  ['FACILITY NAME', 'COUNTRY', 'CITY', 'MainActivityCode', 'emissions', 'YEAR', 'avg_wind_speed ', 'DAYS FOG', 'CITY_ID']
# The diferences between List 6 and List 6 is
#  []

# %% [markdown]
# ### **<span style="color:#43A047;">3.1 Reordering the columns </span>**
# We reorder the columns to give a more logical sense to the datasets. We will place the target variable at the end.

# %%
data1_csv_df = data1_csv_df[['reportingYear', 'MONTH', 'DAY', 'CONTINENT', 'countryName', 'City', 'CITY ID',
                             'eprtrSectorName','EPRTRAnnexIMainActivityLabel', 'FacilityInspireID', 'facilityName',
                             'targetRelease', 'DAY WITH FOGS','max_wind_speed', 'avg_wind_speed', 'min_wind_speed',
                             'max_temp', 'avg_temp', 'min_temp', 'REPORTER NAME', 'pollutant' ]]

# %% [markdown]
# If there is a different order, the data frame in question can be reindexed.

# %%
column_names = ["C", "A", "B"]
df = df.reindex(columns=column_names)

# %% [markdown]
# ### **<span style="color:#43A047;">3.2 Merging all the information in a single data set.  </span>**
#
# #### **<span style="color:#4CAF50;">3.2.1 Vertically merging </span>**

# %%
data = pd.concat([data1_csv_df, data1_json_df,data1_pdf_df,data1_twt_df], ignore_index=True)

# %%
print('The shape of our features is:', data.shape)

# %%
df.describe()

# %% [markdown]
# #### **<span style="color:#4CAF50;">3.2.2 Horizontal merging </span>**

# %%
df2 = df2.reset_index(drop=True) #To reset the index
data = pd.concat([df1,df2], axis=1) #Horizontally concateneting with the same index

# %%
print('The shape of our features is:', data.shape)

# %% [markdown]
# ### **<span style="color:#43A047;">3.3 Checking anomalies or outliers in the entire dataset.  </span>**

# %% [markdown]
# #### **<span style="color:#4CAF50;">3.3.1 Detecting Columns with problems </span>**

# %%
def data_checking (df, sd=2):
    "Autocheking for any Anomalies or Outliers"
    rows_problems = []
    max_problems = []
    min_problems = []
    null_data = []
    for i in range(0,len(data.describe().columns)): #This will check in numeric's columns
        
        if data.describe().iloc[0,i:i+1][0] != data.shape[0]: #Checking rows discordance 
            rows_problems.append(df.describe().columns[i])
       
        #Checking minimum data range
        if int(df.describe().iloc[3,i:i+1][0]) < (int(df.describe().iloc[4,i:i+1][0]) - sd*(int(df.describe().iloc[2,i:i+1][0]))):  
            min_problems.append(df.describe().columns[i])
        
        #Checking maximum data range
        if int(data.describe().iloc[7,i:i+1]) > (int(data.describe().iloc[6,i:i+1]) + sd*int(df.describe().iloc[2,i:i+1][0])): 
            max_problems.append(df.describe().columns[i])
    
    for i in range (0, data.shape[1]): # This will check in the entire DataFrame   
        
        if (df.isnull().sum()[i] != 0) or (df.isna().sum()[i] != 0): #Checking null or nan datas
            null_data.append(df.columns[i])        
    print("Columns with rows discordance: %s" %rows_problems)
    print("Columns with Min. values problems: %s" %min_problems)
    print("Columns with Max. values problems: %s" %max_problems)
    print("Columns with NaN or Nulls: %s" %null_data)
    return rows_problems, min_problems, max_problems, null_data

# %%
sd_multiplier = 2 #Standar Deviation Multiplier to chek how far away the 25% and 75% outliers should be.
row_prblm, min_col, max_col, null_col = data_checking (data, sd_multiplier)

# %% [markdown]
# #### **<span style="color:#4CAF50;">3.3.2 Maximum and Minimum representation for a Data Set </span>**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.plot(X_train.min(axis=0), 'o', label='Min')
plt.plot(X_train.max(axis=0), 'v', label='Max')
plt.xlabel('Feature Index')
plt.ylabel('Feature Magnitude in Log Scale')
plt.yscale('log') #Logarithmic scale to fit all the values.
plt.legend(loc='upper right')

# %% [markdown]
# ### **<span style="color:#43A047;">3.4 Capping and Flooring (Outliers Treatment)  </span>**

# %%
data1 = data.copy() #Making a chekpoint.

# %%
#Otiliers capping according to percentile for each column
percentile = 2
for i in max_col:
    data1[i][(data1[i]>(np.percentile(data1.loc[:,i],[100-percentile])[0]))]= (np.percentile(data1.loc[:,i],[100-percentile])[0])
for i in min_col:
    data1[i][(data1[i]<(np.percentile(data1.loc[:,i],[percentile])[0]))]= (np.percentile(data1.loc[:,i],[percentile])[0])

# %%
data1.describe() #Cheking results

# %% [markdown]
# ### **<span style="color:#43A047;">3.5 Features visualization and comparation </span>**
#
# #### **<span style="color:#4CAF50;">3.5.1 Unvariate Analysis (EDA: Exploratory Data Analysis) </span>**

# %%
cat_cols = data1.select_dtypes(include=['category','object', 'bool_'])
num_cols = data1.select_dtypes(include=['number','int','float'])

# %%
def pie_count_chart (x, data, qty=10):
    """Creates a pie chart of the specific categorical feature chosen."""
    import plotly.subplots as sp
    import plotly.express as px
    df1 = pd.DataFrame()
    df1 = data[[x]].groupby([x])[x] \
                         .count() \
                         .reset_index(name='count') \
                         .sort_values(['count'], ascending=False) \
                         .iloc[:qty]
    
    figure1 = px.pie(df1, values = "count", color_discrete_sequence=px.colors.sequential.RdBu,
                 names = "count", width = 400, height = 400, hover_data=[x], 
                  labels={x:'Date'}, title='Pie Chart of the highest %d (%s)' %(qty, x))
    figure1.show()

# %%
interact(pie_count_chart,
         x = cat_cols.columns,
         data = fixed(cat_cols),
         qty= IntSlider(min=0, max=100, step=1))

# %% [markdown]
# #### **<span style="color:#4CAF50;">3.5.2 Bivariate Analysis (EDA: Exploratory Data Analysis) </span>**

# %%
def plotting_bar (x,y,bar,data,qty):
    import plotly.subplots as sp
    import plotly.express as px
    if x != y:
        df1 = data[[x, y, bar]].groupby([x, bar])[y] \
                                 .count() \
                                 .reset_index(name=y) \
                                 .sort_values([y], ascending=False) \
                                 .head(qty)
        figure1  = px.bar(df1, x=x, y=y, color=str(bar), barmode='group', height=400, width=700 ,
                          title='Bar graph (%s) vs (%s) of the greaters %d ' %(x, y, qty))
        figure1.show()
    else:
        print("Feature selection problem.")

# %%
interact(plotting_bar,
         x= list(data1.columns[:-1]), #Eje x a contrastar
         y= list(data1.columns[:-1]), #Eje y a contrastar (cuantificar)
         bar = fixed(data1.columns[-1]), #Barras a graficar
         data = fixed(data1),
         qty= IntSlider(min=0, max=100, step=1))

# %% [markdown]
# ### **<span style="color:#43A047;">3.6 Creating dummy if necesary</span>**
# (WIP-----------------SEE IF THIS SECTION SHOULD BE BEFORE OR AFTER EDA)

# %%
categories = ["xxx1", "xxx2", "xxx3", "xxx4", "xxx5", "xxx5", "xxx6"]
for category in categories:
    cat_list = "cat" + "_" + category
    cat_dummies = pd.get_dummies(data[category], prefix=cat_list)
    data1 = data1.join(cat_dummies[:-1]) ## WIP THERE IS NOT NECESARY TO ADD ALL THE DUMMY, CAUSE COULD IT BE REDUNDANT
    del data1[category] #Deleting original dummie variable

# %%
data1.head()#quick review if all goes well

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ### ✅  4) Preparing data for training and testing 🏃

# %% [markdown]
# ### **<span style="color:#43A047;">4.1 Variables Stadnarization  </span>**

# %%
X = data1.loc[:, data1.columns != 'TARGET'] # Assing X (feature columns)
y = data1['TARGET']# Assing y (target column)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### **<span style="color:#43A047;">4.1 Variables Stadnarization  </span>**

# %%
scaler = preprocessing.StandardScaler().fit(X_train) #Variables standarization
X_train_s = scaler.transform(X_train) #Variables transform

# %%
train, test = train_test_split(df, test_size = 0.2)
print("Longitud de datos de entrenamiento: %f" %(len(train)), "datos de testing: %f" %(len(test)))

# %%
#Asignación de variables predictoras y target
colnames = df.columns.values.tolist()
predictors=colnames[1:xx]
target=colnames[xx]

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ### ✅ 5) Training the model with training data🏋️

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

# %%
# %%time
def find_best_model_using_gridsearchcv(X,y):
    """Function with three models for classification"""
    
    algos = {
        'Logistic_Regression' : {
        'model': LogisticRegression(),
        'params': {
            'max_iter':[1000, 2000, 5000],
            #'C':[,10,100,1000],
            'solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']  
            }
        },
        'Linear_Discriminant_Analysis': {
        'model': LinearDiscriminantAnalysis(),
        'params': {
            'solver':['svd', 'lsqr', 'eigen']  
            }
        },      
        'K_Nearest_Neighbors':{
            'model' : KNeighborsClassifier(),
            'params':{
            'n_neighbors': [5,10],
            'metric': ["minkowski", 'euclidean', 'manhattan', 'chebyshev', 'wminkowski', 'seuclidean', 'mahalanobis'],
            'p': [2],
            'n_neighbors': range(100)
            }                                                        
        },
        'Decision_Tree_Classifier': {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ['gini','entropy', 'log_loss'],
            'min_samples_split': [10,100,1000],
            'max_depth' :[3,5,10,20],
            'splitter': ['best','random']
            }
        },
        'Random_Forest_Classifier': {
        'model': RandomForestClassifier(),
        'params': {
            'n_jobs' : [multiprocessing.cpu_count() - 1],            
            'n_estimators': [10,100,200,500],
            'max_depth'   : [None, 3, 10, 20],
            'criterion'   : ['gini', 'entropy']
            }
        },      
        'MLP_Classifier': {
        'model': MLPClassifier(),
        'params': {            
            'max_iter':[1000],
            'alpha':[0.001,0.01,0.1,1],
            }
        },      
        'Support_Vector_Classifier': {
        'model': SVC(),
        'params': {
            'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
            'C':[1,100,1000,10000],
            'gamma':[0.0001,0.001,0.01,0.1]
            }
         },       
        #'Gradien_Boosting_Classifier': {
        #'model': GradientBoostingClassifier(),
        #'params':  {
        #    'n_estimators'  : [50, 100, 500, 1000],
        #    'max_features'  : ['auto', 'sqrt', 'log2'],
        #    'max_depth'     : [None, 1, 3, 5, 10, 20],
        #    'subsample'     : [0.5, 1],
        #    'learning_rate' : [0.001, 0.01, 0.1]
        #    }
        #}         
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'], config['params'], cv=cv, return_train_score = True)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        }) 
    return pd.DataFrame(scores,columns=['model','best_score','best_params'])
best = find_best_model_using_gridsearchcv(X_train_s,y_train)

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ### ✅ 6) Making predictions with test data 🤔¶

# %%
def price_predict(location,sqft,bath,BHK):
    loc_index=np.where(X.columns==location)[0][0]
    x=np.zeros(len(X.columns))
    x[0]=sqft
    x[1]=bath
    x[2]=BHK
    if loc_index >=0:
    x[loc_index]=1
    return model.predict([x])[0]

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ### ✅ 7) Comparing predictions with test data📝

# %%
from sklearn.metrics import classification_report
from sklearn import metrics

# %%
#print(classification_report(Y_test, y_pred, target_names=["xxxxx", "xxxxx", "xxxxx"]))

# %%
#print("Homogeneidad: %0.3f" %metrics.homogeneity_score(labels, clust_labels))
#print("Completitud: %0.3f" %metrics.completeness_score(labels, clust_labels))
#print("V-measure: %0.3f" %metrics.v_measure_score(labels, clust_labels))
#print("R2 ajustado: %0.3f" %metrics.adjusted_rand_score(labels, clust_labels))
#print("Información mútua ajustada: %0.3f" %metrics.adjusted_mutual_info_score(labels,clust_labels))

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ### ✅ 8) Adjusting the model🔨

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ### ✅ 9) Results presentation. 🌟

# %% [markdown]
# ### **<span style="color:#43A047;">9.1 Graphical representation of results  </span>**

# %% [markdown]
# ### **<span style="color:#43A047;">9.2 Conclusion  </span>**

# %% [markdown]
# ### **<span style="color:#43A047;">9.3 Making & saving predictions </span>**

# %%
results = pd.DataFrame(pred, columns=['Results'])

# %%
results.to_csv("../../Practice/1-Random Forest/results.csv", index=False)

# %%
results
